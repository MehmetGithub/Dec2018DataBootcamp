# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load csv file data with headers

location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0   ...     -77.01942            Old City 2
# 158953  1938.0   2006.0   ...     -77.01942            Old City 2
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
df.loc

# %%
df[['PRICE','BEDRM','BATHRM','AC', 'ROOMS']]
# Out:
#             PRICE  BEDRM  BATHRM AC  ROOMS
# 0       1095000.0      4       4  Y      8
# 1             NaN      5       3  Y     11
# 2       2100000.0      5       3  Y      9
# 3       1602000.0      5       3  Y      8
# 4             NaN      3       2  Y     11
# 5       1950000.0      5       3  Y     10
# 6             NaN      2       1  Y      5
# 7       1050000.0      4       3  Y      8
# 8       1430000.0      3       3  Y      7
# 9             NaN      2       1  Y      6
# 10            NaN      5       3  N     12
# 11            NaN      6       5  Y     16
# 12            NaN      5       2  N      9
# 13            NaN      5       2  Y     11
# 14      1325000.0      3       3  Y      5
# 15            NaN      4       2  Y      9
# 16      1240000.0      3       3  Y      8
# 17            NaN      3       2  N      6
# 18            NaN      4       3  Y     10
# 19       592250.0      3       3  Y      9
# 20        33232.0      5       3  Y     14
# ...

# %%
df['PRICE'].value_counts()
# Out:
# 350000.0     595
# 250000.0     536
# 300000.0     523
# 450000.0     519
# 375000.0     488
# 325000.0     482
# 550000.0     459
# 275000.0     455
# 500000.0     426
# 320000.0     425
# 200000.0     422
# 425000.0     419
# 600000.0     403
# 315000.0     402
# 330000.0     396
# 650000.0     387
# 525000.0     387
# 285000.0     377
# 225000.0     376
# 265000.0     374
# 310000.0     371
# 475000.0     364
# 360000.0     364
# 260000.0     360
# 280000.0     352
# 385000.0     352
# 335000.0     352
# 220000.0     349
# 240000.0     348
# 230000.0     347
#             ...
# 168700.0       1
# 674755.0       1
# 5397500.0      1
# 168670.0       1
# 674670.0       1
# 468400.0       1
# 337325.0       1
# 1096000.0      1
# 337562.0       1
# 1350250.0      1
# 337575.0       1
# 117164.0       1
# 84461.0        1
# 468890.0       1
# 84450.0        1
# 84449.0        1
# 503850.0       1
# 337750.0       1
# 675490.0       1
# 114620.0       1
# 466250.0       1
# ...

# %%
df.groupby(['PRICE', 'BEDRM','BATHRM', 'FULLADDRESS']).mean()
# Out:
#                                                        Unnamed: 0  HF_BATHRM  \
# PRICE      BEDRM BATHRM FULLADDRESS
# 1.0        3     1      4015 21ST STREET NE                 81694          1
#            6     3      4734 SOUTH CAPITOL TERRACE SW      106683          0
# 10.0       2     1      320 34TH STREET NE                  81594          0
#            3     1      784 LAMONT STREET NW                51658          0
#                  2      1101 HOLBROOK TERRACE NE            74419          0
#                         3014 Q STREET NW                    18568          1
# 250.0      2     1      1249 W STREET SE                   102782          0
#                  2      1416 OAK STREET NW                  43281          0
#                         1645 GALES STREET NE                84165          0
#                         3013 SHERMAN AVENUE NW              49443          0
#                         821 12TH STREET NE                  14041          0
# ...

# %%
#show rows with missing values
missing = df.isnull()
missing
#missing will only show True/False values
df.loc[missing] #getting the rows for us
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-deba683b4ab7> in <module>()
#       1 #show rows with missing values
# ----> 2 missing = df.isnull(false)
#       3 missing
#       4 #missing will only show True/False values
#       5 df.loc[missing] #getting the rows for us
#
# NameError: name 'false' is not defined

# %%
#multiple conditions
df.loc[(df['PRICE'] >= 50000) & (df['PRICE'] < 100000) & (df['BEDRM'] < 4) & (df['YR_RMDL'] >= 2000) & (df['YR_RMDL'] < 2007)] #pick houses between 50K and 100K
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 1104          1104       1          0  Hot Water Rad  N        1.0      6
# 2573          2573       2          1  Hot Water Rad  Y        1.0      8
# 3128          3128       1          1     Forced Air  Y        1.0      7
# 4403          4403       4          0   Wall Furnace  N        4.0      5
# 4818          4818       1          1     Forced Air  Y        1.0      6
# 5433          5433       2          1     Forced Air  Y        1.0      6
# 7387          7387       1          1  Hot Water Rad  N        1.0      6
# 7656          7656       1          0  Hot Water Rad  Y        1.0      6
# 8945          8945       3          1      Warm Cool  Y        2.0      8
# 9963          9963       1          1        Ht Pump  Y        1.0      6
# 10156        10156       2          0     Forced Air  Y        2.0      6
# 10607        10607       1          0      Warm Cool  Y        1.0      4
# ...

# %%
df.loc[(df['YR_RMDL'] >= 2000)] #pick houses after year 2000. Looks like more houses before year 2000
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 14              14       3          1      Warm Cool  Y        2.0      5
# 16              16       3          1      Warm Cool  Y        1.0      8
# 18              18       3          1  Hot Water Rad  Y        2.0     10
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 21              21       3          0     Forced Air  Y        2.0     12
# ...

# %%
df.loc[(df['PRICE'] >= 200000) & (df['PRICE'] < 300000)] #pick houses between 200K and 300K
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 59              59       2          0  Hot Water Rad  N        2.0      9
# 77              77       2          1      Warm Cool  Y        2.0     11
# 132            132       1          0      Warm Cool  Y        1.0      6
# 136            136       1          1  Hot Water Rad  N        1.0      6
# 156            156       2          1      Warm Cool  Y        1.0      6
# 185            185       1          1      Warm Cool  Y        1.0      8
# 231            231       1          1      Warm Cool  Y        1.0      7
# 237            237       1          1      Warm Cool  Y        1.0      5
# 255            255       3          1      Warm Cool  Y        2.0      8
# 264            264       1          0  Hot Water Rad  N        1.0      6
# 277            277       1          1      Warm Cool  Y        1.0      6
# 286            286       2          0      Warm Cool  Y        1.0      7
# ...

# %%
df.loc[(df['PRICE'] >= 200000)] #pick houses more than 200K. This means also atleast 79K houses are cheaper than 200K
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 14              14       3          1      Warm Cool  Y        2.0      5
# 16              16       3          1      Warm Cool  Y        1.0      8
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 22              22       1          0     Forced Air  Y        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# 24              24       2          1  Hot Water Rad  Y        1.0      8
# ...

# %%
#replace empty cells with 1111
df.fillna(1111)
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#drops duplicate rows, default is to keep first observation
df.drop_duplicates()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
#keep last observation
df.drop_duplicates(['FULLADDRESS'], keep='last')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df = pd.read_csv("datasets/DC_Properties.csv") # Missing dataaaaaaa
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
#Selecting rows with no missing age or gender
df[df['FULLADDRESS'].notnull() & df['PRICE'].notnull()& df['YR_RMDL'].notnull()]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 14              14       3          1      Warm Cool  Y        2.0      5
# 16              16       3          1      Warm Cool  Y        1.0      8
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 22              22       1          0     Forced Air  Y        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# 24              24       2          1  Hot Water Rad  Y        1.0      8
# ...

# %%
df2=df['FULLADDRESS','PRICE','YR_RMDL','AC','HEAT','SQUARE']
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('FULLADDRESS', 'PRICE', 'YR_RMDL', 'AC', 'HEAT', 'SQUARE')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#drop rows with any missing data
df_no_missing = df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
addRemove = list(zip(FULLADDRESS,BEDRM,PRICE,YR_RMDL))

df = pd.DataFrame(data = GradeList, columns=['Names','Grades','BS','MS','PhD'])
df
